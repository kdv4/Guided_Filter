# %% [markdown]
# # IT-507 Advanced Image Processing
# ## Project Title: Guided Filter
# ### Author: 202011004: Kishan Vaishnani, 20201132: Dhyanil Mehta

# %%
# !sudo apt-get update
# !sudo apt install -y libgtk2.0-dev
# Out:
# Get:1 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1,344 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,182 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,550 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [429 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.3 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.7 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,119 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [399 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,410 kB]
# Fetched 22.5 MB in 2s (9,096 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   adwaita-icon-theme autoconf automake autopoint autotools-dev binutils
#   binutils-common binutils-x86-64-linux-gnu bsdmainutils build-essential cpp
#   cpp-7 debhelper dh-autoreconf dh-strip-nondeterminism dirmngr dpkg-dev
#   fakeroot file fontconfig g++ g++-7 gcc gcc-7 gcc-7-base gettext gettext-base
#   gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0
#   gir1.2-gtk-2.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 gnupg gnupg-l10n
#   gnupg-utils gpg gpg-agent gpg-wks-client gpg-wks-server gpgconf gpgsm gpgv
#   groff-base gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme
#   icu-devtools intltool-debian libalgorithm-diff-perl
#   libalgorithm-diff-xs-perl libalgorithm-merge-perl libarchive-cpio-perl
#   libarchive-zip-perl libasan4 libassuan0 libatk1.0-0 libatk1.0-data
#   libatk1.0-dev libatomic1 libbinutils libc-dev-bin libc6-dev
#   libcairo-gobject2 libcairo-script-interpreter2 libcairo2 libcairo2-dev
#   libcc1-0 libcilkrts5 libcroco3 libdatrie1 libdpkg-perl libexpat1-dev
#   libfakeroot libfile-fcntllock-perl libfile-stripnondeterminism-perl
#   libfontconfig1-dev libfreetype6-dev libgail-common libgail18 libgcc-7-dev
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgdk-pixbuf2.0-dev libgirepository-1.0-1 libglib2.0-0 libglib2.0-bin
#   libglib2.0-data libglib2.0-dev libglib2.0-dev-bin libgomp1 libgraphite2-3
#   libgraphite2-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libharfbuzz-dev
#   libharfbuzz-gobject0 libharfbuzz-icu0 libharfbuzz0b libice-dev libice6
#   libicu-dev libicu-le-hb-dev libicu-le-hb0 libicu60 libiculx60 libisl19
#   libitm1 libjbig0 libksba8 liblocale-gettext-perl liblsan0 libltdl-dev
#   libltdl7 liblzo2-2 libmagic-mgc libmagic1 libmail-sendmail-perl libmpc3
#   libmpdec2 libmpfr6 libmpx2 libnpth0 libpango-1.0-0 libpango1.0-dev
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpangoxft-1.0-0 libpcre16-3
#   libpcre3-dev libpcre32-3 libpcrecpp0v5 libpipeline1 libpixman-1-0
#   libpixman-1-dev libpng-dev libpng-tools libpthread-stubs0-dev
#   libpython-stdlib libpython2.7-minimal libpython2.7-stdlib libpython3-stdlib
#   libpython3.6-minimal libpython3.6-stdlib libquadmath0 libreadline7
#   librsvg2-2 librsvg2-common libsigsegv2 libsm-dev libsm6 libstdc++-7-dev
#   libsys-hostname-long-perl libthai-data libthai0 libtiff5 libtimedate-perl
#   libtool libtsan0 libubsan0 libx11-dev libx11-doc libxau-dev libxcb-render0
#   libxcb-render0-dev libxcb-shm0 libxcb-shm0-dev libxcb1-dev libxcomposite-dev
#   libxcomposite1 libxcursor-dev libxcursor1 libxdamage-dev libxdmcp-dev
#   libxext-dev libxfixes-dev libxft-dev libxft2 libxi-dev libxinerama-dev
#   libxinerama1 libxml2 libxml2-utils libxrandr-dev libxrandr2 libxrender-dev
#   linux-libc-dev m4 make man-db manpages manpages-dev mime-support
#   pinentry-curses pkg-config po-debconf python python-minimal python2.7
#   python2.7-minimal python3 python3-distutils python3-lib2to3 python3-minimal
#   python3.6 python3.6-minimal readline-common shared-mime-info ubuntu-mono
#   x11proto-composite-dev x11proto-core-dev x11proto-damage-dev x11proto-dev
#   x11proto-fixes-dev x11proto-input-dev x11proto-randr-dev x11proto-xext-dev
#   x11proto-xinerama-dev xdg-user-dirs xorg-sgml-doctools xtrans-dev xz-utils
#   zlib1g-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc binutils-doc wamerican
#   | wordlist whois vacation cpp-doc gcc-7-locales dh-make dwz
#   dbus-user-session libpam-systemd pinentry-gnome3 tor debian-keyring
#   g++-multilib g++-7-multilib gcc-7-doc libstdc++6-7-dbg gcc-multilib flex
#   bison gdb gcc-doc gcc-7-multilib libgcc1-dbg libgomp1-dbg libitm1-dbg
#   libatomic1-dbg libasan4-dbg liblsan0-dbg libtsan0-dbg libubsan0-dbg
#   libcilkrts5-dbg libmpx2-dbg libquadmath0-dbg gettext-doc libasprintf-dev
#   libgettextpo-dev parcimonie xloadimage scdaemon groff glibc-doc
#   libcairo2-doc bzr libglib2.0-doc libgraphite2-utils gvfs libgtk2.0-doc
#   libice-doc icu-doc libtool-doc imagemagick libpango1.0-doc librsvg2-bin
#   libsm-doc libstdc++-7-doc gfortran | fortran95-compiler gcj-jdk libxcb-doc
#   libxext-doc m4-doc make-doc apparmor www-browser pinentry-doc
#   libmail-box-perl python-doc python-tk python2.7-doc binfmt-support
#   python3-doc python3-tk python3-venv python3.6-venv python3.6-doc
#   readline-doc
# The following NEW packages will be installed:
#   adwaita-icon-theme autoconf automake autopoint autotools-dev binutils
#   binutils-common binutils-x86-64-linux-gnu bsdmainutils build-essential cpp
#   cpp-7 debhelper dh-autoreconf dh-strip-nondeterminism dirmngr dpkg-dev
#   fakeroot file fontconfig g++ g++-7 gcc gcc-7 gcc-7-base gettext gettext-base
#   gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0
#   gir1.2-gtk-2.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 gnupg gnupg-l10n
#   gnupg-utils gpg gpg-agent gpg-wks-client gpg-wks-server gpgconf gpgsm
#   groff-base gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme
#   icu-devtools intltool-debian libalgorithm-diff-perl
#   libalgorithm-diff-xs-perl libalgorithm-merge-perl libarchive-cpio-perl
#   libarchive-zip-perl libasan4 libassuan0 libatk1.0-0 libatk1.0-data
#   libatk1.0-dev libatomic1 libbinutils libc-dev-bin libc6-dev
#   libcairo-gobject2 libcairo-script-interpreter2 libcairo2 libcairo2-dev
#   libcc1-0 libcilkrts5 libcroco3 libdatrie1 libdpkg-perl libexpat1-dev
#   libfakeroot libfile-fcntllock-perl libfile-stripnondeterminism-perl
#   libfontconfig1-dev libfreetype6-dev libgail-common libgail18 libgcc-7-dev
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgdk-pixbuf2.0-dev libgirepository-1.0-1 libglib2.0-0 libglib2.0-bin
#   libglib2.0-data libglib2.0-dev libglib2.0-dev-bin libgomp1 libgraphite2-3
#   libgraphite2-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgtk2.0-dev
#   libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0 libharfbuzz0b
#   libice-dev libice6 libicu-dev libicu-le-hb-dev libicu-le-hb0 libicu60
#   libiculx60 libisl19 libitm1 libjbig0 libksba8 liblocale-gettext-perl
#   liblsan0 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc libmagic1
#   libmail-sendmail-perl libmpc3 libmpdec2 libmpfr6 libmpx2 libnpth0
#   libpango-1.0-0 libpango1.0-dev libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpangoxft-1.0-0 libpcre16-3 libpcre3-dev libpcre32-3 libpcrecpp0v5
#   libpipeline1 libpixman-1-0 libpixman-1-dev libpng-dev libpng-tools
#   libpthread-stubs0-dev libpython-stdlib libpython2.7-minimal
#   libpython2.7-stdlib libpython3-stdlib libpython3.6-minimal
#   libpython3.6-stdlib libquadmath0 libreadline7 librsvg2-2 librsvg2-common
#   libsigsegv2 libsm-dev libsm6 libstdc++-7-dev libsys-hostname-long-perl
#   libthai-data libthai0 libtiff5 libtimedate-perl libtool libtsan0 libubsan0
#   libx11-dev libx11-doc libxau-dev libxcb-render0 libxcb-render0-dev
#   libxcb-shm0 libxcb-shm0-dev libxcb1-dev libxcomposite-dev libxcomposite1
#   libxcursor-dev libxcursor1 libxdamage-dev libxdmcp-dev libxext-dev
#   libxfixes-dev libxft-dev libxft2 libxi-dev libxinerama-dev libxinerama1
#   libxml2 libxml2-utils libxrandr-dev libxrandr2 libxrender-dev linux-libc-dev
#   m4 make man-db manpages manpages-dev mime-support pinentry-curses pkg-config
#   po-debconf python python-minimal python2.7 python2.7-minimal python3
#   python3-distutils python3-lib2to3 python3-minimal python3.6
#   python3.6-minimal readline-common shared-mime-info ubuntu-mono
#   x11proto-composite-dev x11proto-core-dev x11proto-damage-dev x11proto-dev
#   x11proto-fixes-dev x11proto-input-dev x11proto-randr-dev x11proto-xext-dev
#   x11proto-xinerama-dev xdg-user-dirs xorg-sgml-doctools xtrans-dev xz-utils
#   zlib1g-dev
# The following packages will be upgraded:
#   gpgv
# 1 upgraded, 226 newly installed, 0 to remove and 20 not upgraded.
# Need to get 106 MB of archives.
# After this operation, 451 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblocale-gettext-perl amd64 1.07-3build2 [16.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-minimal amd64 3.6.9-1~18.04ubuntu1.4 [534 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-minimal amd64 3.6.9-1~18.04ubuntu1.4 [1,610 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-minimal amd64 3.6.7-1~18.04 [23.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 mime-support all 3.60ubuntu1 [30.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpdec2 amd64 2.4.2-1ubuntu1 [84.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 readline-common all 7.0-3 [52.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libreadline7 amd64 7.0-3 [124 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-stdlib amd64 3.6.9-1~18.04ubuntu1.4 [1,712 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6 amd64 3.6.9-1~18.04ubuntu1.4 [203 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3-stdlib amd64 3.6.7-1~18.04 [7,240 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3 amd64 3.6.7-1~18.04 [47.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 bsdmainutils amd64 11.1.2ubuntu1 [181 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 groff-base amd64 1.22.3-10 [1,153 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpipeline1 amd64 1.5.0-1 [25.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 man-db amd64 2.8.3-2ubuntu0.1 [1,019 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig amd64 2.12.6-0ubuntu2 [169 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice6 amd64 2:1.0.9-2 [40.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsm6 amd64 2:1.2.2-1 [15.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxft2 amd64 2.3.2-1 [36.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-minimal amd64 2.7.17-1~18.04ubuntu1.6 [335 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python2.7-minimal amd64 2.7.17-1~18.04ubuntu1.6 [1,291 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-minimal amd64 2.7.15~rc1-1 [28.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-stdlib amd64 2.7.17-1~18.04ubuntu1.6 [1,917 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python2.7 amd64 2.7.17-1~18.04ubuntu1.6 [248 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpython-stdlib amd64 2.7.15~rc1-1 [7,620 B]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 python amd64 2.7.15~rc1-1 [140 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpgv amd64 2.2.4-1ubuntu1.4 [198 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-0 amd64 2.56.4-0ubuntu0.18.04.8 [1,171 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgirepository-1.0-1 amd64 1.56.1-1 [82.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-glib-2.0 amd64 1.56.1-1 [131 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-data all 2.56.4-0ubuntu0.18.04.8 [4,716 B]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libicu60 amd64 60.2-3ubuntu3.1 [8,054 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2 amd64 2.9.4+dfsg1-6.1ubuntu1.3 [663 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 shared-mime-info amd64 1.9-2 [426 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 xdg-user-dirs amd64 0.17-1ubuntu1 [48.0 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 xz-utils amd64 5.2.2-1.3 [83.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 manpages all 4.15-1 [1,234 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 hicolor-icon-theme all 0.17-2 [9,976 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtiff5 amd64 4.0.9-5ubuntu0.4 [153 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4,536 B]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gtk-update-icon-cache amd64 3.22.30-1ubuntu4 [28.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-0 amd64 0.34.0-2 [229 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-render0 amd64 1.13-2~ubuntu18.04 [14.7 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0 amd64 1.13-2~ubuntu18.04 [5,600 B]
# Get:54 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2 amd64 1.15.10-2ubuntu0.1 [580 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcroco3 amd64 0.6.12-2 [81.3 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai-data all 0.1.27-2 [133 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdatrie1 amd64 0.2.10-7 [17.8 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai0 amd64 0.1.27-2 [18.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango-1.0-0 amd64 1.40.14-1ubuntu0.1 [153 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphite2-3 amd64 1.3.11-2 [78.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz0b amd64 1.7.2-1ubuntu1 [232 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoft2-1.0-0 amd64 1.40.14-1ubuntu0.1 [33.2 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangocairo-1.0-0 amd64 1.40.14-1ubuntu0.1 [20.8 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-2 amd64 2.40.20-2ubuntu0.2 [98.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-common amd64 2.40.20-2ubuntu0.2 [5,064 B]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 humanity-icon-theme all 0.6.15 [1,250 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-mono all 16.10+18.04.20181005-0ubuntu1 [149 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/main amd64 adwaita-icon-theme all 3.28.0-1ubuntu1 [3,306 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-common amd64 2.30-21ubuntu1~18.04.5 [197 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbinutils amd64 2.30-21ubuntu1~18.04.5 [489 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.30-21ubuntu1~18.04.5 [1,839 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils amd64 2.30-21ubuntu1~18.04.5 [3,388 B]
# Get:79 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libc-dev-bin amd64 2.27-3ubuntu1.4 [71.8 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-142.146 [987 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libc6-dev amd64 2.27-3ubuntu1.4 [2,585 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gcc-7-base amd64 7.5.0-3ubuntu1~18.04 [18.3 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 libisl19 amd64 0.19-1 [551 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpfr6 amd64 4.0.1-1 [243 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpc3 amd64 1.1.0-1 [40.8 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 cpp-7 amd64 7.5.0-3ubuntu1~18.04 [8,591 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 cpp amd64 4:7.4.0-1ubuntu2.3 [27.7 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcc1-0 amd64 8.4.0-1ubuntu1~18.04 [39.4 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgomp1 amd64 8.4.0-1ubuntu1~18.04 [76.5 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libitm1 amd64 8.4.0-1ubuntu1~18.04 [27.9 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libatomic1 amd64 8.4.0-1ubuntu1~18.04 [9,192 B]
# Get:92 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasan4 amd64 7.5.0-3ubuntu1~18.04 [358 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblsan0 amd64 8.4.0-1ubuntu1~18.04 [133 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtsan0 amd64 8.4.0-1ubuntu1~18.04 [288 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libubsan0 amd64 7.5.0-3ubuntu1~18.04 [126 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcilkrts5 amd64 7.5.0-3ubuntu1~18.04 [42.5 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmpx2 amd64 8.4.0-1ubuntu1~18.04 [11.6 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libquadmath0 amd64 8.4.0-1ubuntu1~18.04 [134 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgcc-7-dev amd64 7.5.0-3ubuntu1~18.04 [2,378 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gcc-7 amd64 7.5.0-3ubuntu1~18.04 [9,381 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gcc amd64 4:7.4.0-1ubuntu2.3 [5,184 B]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libstdc++-7-dev amd64 7.5.0-3ubuntu1~18.04 [1,471 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 g++-7 amd64 7.5.0-3ubuntu1~18.04 [9,697 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 g++ amd64 4:7.4.0-1ubuntu2.3 [1,568 B]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/main amd64 make amd64 4.1-9.1ubuntu1 [154 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdpkg-perl all 1.19.0.5ubuntu2.3 [211 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dpkg-dev all 1.19.0.5ubuntu2.3 [607 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 build-essential amd64 12.4ubuntu1 [4,758 B]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:115 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/main amd64 libassuan0 amd64 2.5.1-2 [35.0 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpgconf amd64 2.2.4-1ubuntu1.4 [123 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/main amd64 libksba8 amd64 1.3.5-2 [92.6 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnpth0 amd64 1.5-3 [7,668 B]
# Get:123 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dirmngr amd64 2.2.4-1ubuntu1.4 [316 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfakeroot amd64 1.22-2ubuntu1 [25.9 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/main amd64 fakeroot amd64 1.22-2ubuntu1 [62.3 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-data all 2.28.1-1 [2,992 B]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-0 amd64 2.28.1-1 [43.9 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6,988 B]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor1 amd64 1:1.1.15-1 [19.8 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-harfbuzz-0.0 amd64 1.7.2-1ubuntu1 [18.6 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg-l10n all 2.2.4-1ubuntu1.4 [49.8 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg-utils amd64 2.2.4-1ubuntu1.4 [128 kB]
# Get:142 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg amd64 2.2.4-1ubuntu1.4 [467 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/main amd64 pinentry-curses amd64 1.1.0-1 [35.8 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-agent amd64 2.2.4-1ubuntu1.4 [227 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-wks-client amd64 2.2.4-1ubuntu1.4 [91.8 kB]
# Get:146 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpg-wks-server amd64 2.2.4-1ubuntu1.4 [85.0 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gpgsm amd64 2.2.4-1ubuntu1.4 [215 kB]
# Get:148 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnupg amd64 2.2.4-1ubuntu1.4 [249 kB]
# Get:149 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 icu-devtools amd64 60.2-3ubuntu3.1 [179 kB]
# Get:150 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-diff-perl all 1.19.03-1 [47.6 kB]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-diff-xs-perl amd64 0.04-5 [11.1 kB]
# Get:152 http://archive.ubuntu.com/ubuntu bionic/main amd64 libalgorithm-merge-perl all 0.08-3 [12.0 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/main amd64 pkg-config amd64 0.29.1-0ubuntu2 [45.0 kB]
# Get:155 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-bin amd64 2.56.4-0ubuntu0.18.04.8 [68.5 kB]
# Get:156 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-lib2to3 all 3.6.9-1~18.04 [77.4 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-distutils all 3.6.9-1~18.04 [144 kB]
# Get:158 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev-bin amd64 2.56.4-0ubuntu0.18.04.8 [102 kB]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre16-3 amd64 2:8.39-9 [147 kB]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre32-3 amd64 2:8.39-9 [138 kB]
# Get:161 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcrecpp0v5 amd64 2:8.39-9 [15.3 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpcre3-dev amd64 2:8.39-9 [537 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/main amd64 zlib1g-dev amd64 1:1.2.11.dfsg-0ubuntu2 [176 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev amd64 2.56.4-0ubuntu0.18.04.8 [1,386 kB]
# Get:165 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:166 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-gobject2 amd64 1.15.10-2ubuntu0.1 [17.1 kB]
# Get:167 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:168 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1-dev amd64 2.2.5-3ubuntu0.2 [122 kB]
# Get:169 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpng-dev amd64 1.6.34-1ubuntu0.18.04.2 [177 kB]
# Get:170 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libfreetype6-dev amd64 2.8.1-2ubuntu2.1 [2,539 kB]
# Get:171 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontconfig1-dev amd64 2.12.6-0ubuntu2 [689 kB]
# Get:172 http://archive.ubuntu.com/ubuntu bionic/main amd64 xorg-sgml-doctools all 1:1.11-1 [12.9 kB]
# Get:173 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dev all 2018.4-4 [251 kB]
# Get:174 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-core-dev all 2018.4-4 [2,620 B]
# Get:175 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxau-dev amd64 1:1.0.8-1ubuntu1 [9,476 B]
# Get:176 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdmcp-dev amd64 1:1.1.2-3 [25.1 kB]
# Get:177 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-input-dev all 2018.4-4 [2,620 B]
# Get:178 http://archive.ubuntu.com/ubuntu bionic/main amd64 xtrans-dev all 1.3.5-1 [70.5 kB]
# Get:179 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpthread-stubs0-dev amd64 0.3-4 [4,068 B]
# Get:180 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb1-dev amd64 1.13-2~ubuntu18.04 [80.0 kB]
# Get:181 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-dev amd64 2:1.6.4-3ubuntu0.3 [643 kB]
# Get:182 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrender-dev amd64 1:0.9.10-1 [24.9 kB]
# Get:183 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xext-dev all 2018.4-4 [2,620 B]
# Get:184 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxext-dev amd64 2:1.3.3-1 [82.1 kB]
# Get:185 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice-dev amd64 2:1.0.9-2 [46.8 kB]
# Get:186 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsm-dev amd64 2:1.2.2-1 [16.2 kB]
# Get:187 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:188 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-render0-dev amd64 1.13-2~ubuntu18.04 [18.4 kB]
# Get:189 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:190 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:191 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-fcntllock-perl amd64 0.22-3build2 [33.2 kB]
# Get:192 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:193 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:194 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7,864 B]
# Get:195 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:196 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphite2-dev amd64 1.3.11-2 [14.5 kB]
# Get:197 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:198 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-icu0 amd64 1.7.2-1ubuntu1 [5,604 B]
# Get:199 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-gobject0 amd64 1.7.2-1ubuntu1 [13.4 kB]
# Get:200 http://archive.ubuntu.com/ubuntu bionic/main amd64 libicu-le-hb0 amd64 1.0.3+git161113-4 [14.3 kB]
# Get:201 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libiculx60 amd64 60.2-3ubuntu3.1 [19.0 kB]
# Get:202 http://archive.ubuntu.com/ubuntu bionic/main amd64 libicu-le-hb-dev amd64 1.0.3+git161113-4 [29.5 kB]
# Get:203 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libicu-dev amd64 60.2-3ubuntu3.1 [8,889 kB]
# Get:204 http://archive.ubuntu.com/ubuntu bionic/main amd64 libharfbuzz-dev amd64 1.7.2-1ubuntu1 [302 kB]
# Get:205 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxft-dev amd64 2.3.2-1 [45.7 kB]
# Get:206 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:207 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:208 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:209 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fixes-dev all 1:2018.4-4 [2,620 B]
# Get:210 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes-dev amd64 1:5.0.3-1 [11.0 kB]
# Get:211 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi-dev amd64 2:1.7.9-1 [186 kB]
# Get:212 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:213 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:214 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:215 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:216 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:217 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-damage-dev all 1:2018.4-4 [2,620 B]
# Get:218 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage-dev amd64 1:1.1.4-3 [5,028 B]
# Get:219 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.3 [35.9 kB]
# Get:220 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:221 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:222 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl-dev amd64 2.4.6-2 [162 kB]
# Get:223 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:224 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:225 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpng-tools amd64 1.6.34-1ubuntu0.18.04.2 [25.6 kB]
# Get:226 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-doc all 2:1.6.4-3ubuntu0.3 [2,065 kB]
# Get:227 http://archive.ubuntu.com/ubuntu bionic/main amd64 manpages-dev all 4.15-1 [2,217 kB]
# Fetched 106 MB in 3s (36.9 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 9599 files and directories currently installed.)
# Preparing to unpack .../liblocale-gettext-perl_1.07-3build2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking liblocale-gettext-perl (1.07-3build2) ...
# Selecting previously unselected package libpython3.6-minimal:amd64.
# Preparing to unpack .../libpython3.6-minimal_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package python3.6-minimal.
# Preparing to unpack .../python3.6-minimal_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6-minimal (3.6.9-1~18.04ubuntu1.4) ...
# Setting up libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up python3.6-minimal (3.6.9-1~18.04ubuntu1.4) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package python3-minimal.
# (Reading database ... 9851 files and directories currently installed.)
# Preparing to unpack .../0-python3-minimal_3.6.7-1~18.04_amd64.deb ...
# Unpacking python3-minimal (3.6.7-1~18.04) ...
# Selecting previously unselected package mime-support.
# Preparing to unpack .../1-mime-support_3.60ubuntu1_all.deb ...
# Unpacking mime-support (3.60ubuntu1) ...
# Selecting previously unselected package libmpdec2:amd64.
# Preparing to unpack .../2-libmpdec2_2.4.2-1ubuntu1_amd64.deb ...
# Unpacking libmpdec2:amd64 (2.4.2-1ubuntu1) ...
# Selecting previously unselected package readline-common.
# Preparing to unpack .../3-readline-common_7.0-3_all.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking readline-common (7.0-3) ...
# Selecting previously unselected package libreadline7:amd64.
# Preparing to unpack .../4-libreadline7_7.0-3_amd64.deb ...
# Unpacking libreadline7:amd64 (7.0-3) ...
# Selecting previously unselected package libpython3.6-stdlib:amd64.
# Preparing to unpack .../5-libpython3.6-stdlib_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package python3.6.
# Preparing to unpack .../6-python3.6_3.6.9-1~18.04ubuntu1.4_amd64.deb ...
# Unpacking python3.6 (3.6.9-1~18.04ubuntu1.4) ...
# Selecting previously unselected package libpython3-stdlib:amd64.
# Preparing to unpack .../7-libpython3-stdlib_3.6.7-1~18.04_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# Setting up python3-minimal (3.6.7-1~18.04) ...
# Selecting previously unselected package python3.
# (Reading database ... 10303 files and directories currently installed.)
# Preparing to unpack .../00-python3_3.6.7-1~18.04_amd64.deb ...
# Unpacking python3 (3.6.7-1~18.04) ...
# Selecting previously unselected package bsdmainutils.
# Preparing to unpack .../01-bsdmainutils_11.1.2ubuntu1_amd64.deb ...
# Unpacking bsdmainutils (11.1.2ubuntu1) ...
# Selecting previously unselected package groff-base.
# Preparing to unpack .../02-groff-base_1.22.3-10_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking groff-base (1.22.3-10) ...
# Selecting previously unselected package libpipeline1:amd64.
# Preparing to unpack .../03-libpipeline1_1.5.0-1_amd64.deb ...
# Unpacking libpipeline1:amd64 (1.5.0-1) ...
# Selecting previously unselected package man-db.
# Preparing to unpack .../04-man-db_2.8.3-2ubuntu0.1_amd64.deb ...
# Unpacking man-db (2.8.3-2ubuntu0.1) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../05-fontconfig_2.12.6-0ubuntu2_amd64.deb ...
# Unpacking fontconfig (2.12.6-0ubuntu2) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../06-liblzo2-2_2.08-1.2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.08-1.2) ...
# Selecting previously unselected package libice6:amd64.
# Preparing to unpack .../07-libice6_2%3a1.0.9-2_amd64.deb ...
# Unpacking libice6:amd64 (2:1.0.9-2) ...
# Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../08-libsm6_2%3a1.2.2-1_amd64.deb ...
# Unpacking libsm6:amd64 (2:1.2.2-1) ...
# Selecting previously unselected package libxft2:amd64.
# Preparing to unpack .../09-libxft2_2.3.2-1_amd64.deb ...
# Unpacking libxft2:amd64 (2.3.2-1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libxinerama1:amd64.
# Preparing to unpack .../10-libxinerama1_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama1:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package libpython2.7-minimal:amd64.
# Preparing to unpack .../11-libpython2.7-minimal_2.7.17-1~18.04ubuntu1.6_amd64.deb ...
# Unpacking libpython2.7-minimal:amd64 (2.7.17-1~18.04ubuntu1.6) ...
# Selecting previously unselected package python2.7-minimal.
# Preparing to unpack .../12-python2.7-minimal_2.7.17-1~18.04ubuntu1.6_amd64.deb ...
# Unpacking python2.7-minimal (2.7.17-1~18.04ubuntu1.6) ...
# Selecting previously unselected package python-minimal.
# Preparing to unpack .../13-python-minimal_2.7.15~rc1-1_amd64.deb ...
# Unpacking python-minimal (2.7.15~rc1-1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libpython2.7-stdlib:amd64.
# Preparing to unpack .../14-libpython2.7-stdlib_2.7.17-1~18.04ubuntu1.6_amd64.deb ...
# Unpacking libpython2.7-stdlib:amd64 (2.7.17-1~18.04ubuntu1.6) ...
# Selecting previously unselected package python2.7.
# Preparing to unpack .../15-python2.7_2.7.17-1~18.04ubuntu1.6_amd64.deb ...
# Unpacking python2.7 (2.7.17-1~18.04ubuntu1.6) ...
# Selecting previously unselected package libpython-stdlib:amd64.
# Preparing to unpack .../16-libpython-stdlib_2.7.15~rc1-1_amd64.deb ...
# Unpacking libpython-stdlib:amd64 (2.7.15~rc1-1) ...
# Setting up libpython2.7-minimal:amd64 (2.7.17-1~18.04ubuntu1.6) ...
# 7Progress: [  8%] [####......................................................] 8Setting up python2.7-minimal (2.7.17-1~18.04ubuntu1.6) ...
# Linking and byte-compiling packages for runtime python2.7...
# Setting up python-minimal (2.7.15~rc1-1) ...
# Selecting previously unselected package python.
# (Reading database ... 11687 files and directories currently installed.)
# Preparing to unpack .../python_2.7.15~rc1-1_amd64.deb ...
# Unpacking python (2.7.15~rc1-1) ...
# Preparing to unpack .../gpgv_2.2.4-1ubuntu1.4_amd64.deb ...
# Unpacking gpgv (2.2.4-1ubuntu1.4) over (2.2.4-1ubuntu1.3) ...
# Setting up gpgv (2.2.4-1ubuntu1.4) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libmagic-mgc.
# (Reading database ... 11745 files and directories currently installed.)
# Preparing to unpack .../000-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../001-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../002-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libglib2.0-0:amd64.
# Preparing to unpack .../003-libglib2.0-0_2.56.4-0ubuntu0.18.04.8_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# Selecting previously unselected package libgirepository-1.0-1:amd64.
# Preparing to unpack .../004-libgirepository-1.0-1_1.56.1-1_amd64.deb ...
# Unpacking libgirepository-1.0-1:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-glib-2.0:amd64.
# Preparing to unpack .../005-gir1.2-glib-2.0_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-glib-2.0:amd64 (1.56.1-1) ...
# Selecting previously unselected package libglib2.0-data.
# Preparing to unpack .../006-libglib2.0-data_2.56.4-0ubuntu0.18.04.8_all.deb ...
# Unpacking libglib2.0-data (2.56.4-0ubuntu0.18.04.8) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libicu60:amd64.
# Preparing to unpack .../007-libicu60_60.2-3ubuntu3.1_amd64.deb ...
# Unpacking libicu60:amd64 (60.2-3ubuntu3.1) ...
# Selecting previously unselected package libxml2:amd64.
# Preparing to unpack .../008-libxml2_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Selecting previously unselected package shared-mime-info.
# Preparing to unpack .../009-shared-mime-info_1.9-2_amd64.deb ...
# Unpacking shared-mime-info (1.9-2) ...
# Selecting previously unselected package xdg-user-dirs.
# Preparing to unpack .../010-xdg-user-dirs_0.17-1ubuntu1_amd64.deb ...
# Unpacking xdg-user-dirs (0.17-1ubuntu1) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package xz-utils.
# Preparing to unpack .../011-xz-utils_5.2.2-1.3_amd64.deb ...
# Unpacking xz-utils (5.2.2-1.3) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../012-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package manpages.
# Preparing to unpack .../013-manpages_4.15-1_all.deb ...
# Unpacking manpages (4.15-1) ...
# Selecting previously unselected package hicolor-icon-theme.
# Preparing to unpack .../014-hicolor-icon-theme_0.17-2_all.deb ...
# Unpacking hicolor-icon-theme (0.17-2) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../015-libjbig0_2.1-3.1build1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1build1) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../016-libtiff5_4.0.9-5ubuntu0.4_amd64.deb ...
# Unpacking libtiff5:amd64 (4.0.9-5ubuntu0.4) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../017-libgdk-pixbuf2.0-common_2.36.11-2_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.36.11-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../018-libgdk-pixbuf2.0-0_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../019-gtk-update-icon-cache_3.22.30-1ubuntu4_amd64.deb ...
# No diversion 'diversion of /usr/sbin/update-icon-caches to /usr/sbin/update-icon-caches.gtk2 by libgtk-3-bin', none removed.
# No diversion 'diversion of /usr/share/man/man8/update-icon-caches.8.gz to /usr/share/man/man8/update-icon-caches.gtk2.8.gz by libgtk-3-bin', none removed.
# Unpacking gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../020-libpixman-1-0_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../021-libxcb-render0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../022-libxcb-shm0_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libxcb-shm0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../023-libcairo2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../024-libcroco3_0.6.12-2_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.12-2) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../025-libthai-data_0.1.27-2_all.deb ...
# Unpacking libthai-data (0.1.27-2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../026-libdatrie1_0.2.10-7_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.10-7) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../027-libthai0_0.1.27-2_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.27-2) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../028-libpango-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../029-libgraphite2-3_1.3.11-2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.11-2) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../030-libharfbuzz0b_1.7.2-1ubuntu1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../031-libpangoft2-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../032-libpangocairo-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../033-librsvg2-2_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../034-librsvg2-common_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../035-humanity-icon-theme_0.6.15_all.deb ...
# Unpacking humanity-icon-theme (0.6.15) ...
# Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../036-ubuntu-mono_16.10+18.04.20181005-0ubuntu1_all.deb ...
# Unpacking ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# Selecting previously unselected package adwaita-icon-theme.
# ...
# Setting up x11proto-damage-dev (1:2018.4-4) ...
# Setting up libmpx2:amd64 (8.4.0-1ubuntu1~18.04) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libpixman-1-0:amd64 (0.34.0-2) ...
# Setting up xtrans-dev (1.3.5-1) ...
# Setting up gir1.2-glib-2.0:amd64 (1.56.1-1) ...
# Setting up x11proto-xext-dev (2018.4-4) ...
# Setting up libxcursor1:amd64 (1:1.1.15-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libglib2.0-data (2.56.4-0ubuntu0.18.04.8) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.2-3) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libatk1.0-0:amd64 (2.28.1-1) ...
# Setting up xz-utils (5.2.2-1.3) ...
# update-alternatives: using /usr/bin/xz to provide /usr/bin/lzma (lzma) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzma.1.gz because associated file /usr/share/man/man1/xz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/unlzma.1.gz because associated file /usr/share/man/man1/unxz.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcat.1.gz because associated file /usr/share/man/man1/xzcat.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzmore.1.gz because associated file /usr/share/man/man1/xzmore.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzless.1.gz because associated file /usr/share/man/man1/xzless.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzdiff.1.gz because associated file /usr/share/man/man1/xzdiff.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzcmp.1.gz because associated file /usr/share/man/man1/xzcmp.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzgrep.1.gz because associated file /usr/share/man/man1/xzgrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzegrep.1.gz because associated file /usr/share/man/man1/xzegrep.1.gz (of link group lzma) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/lzfgrep.1.gz because associated file /usr/share/man/man1/xzfgrep.1.gz (of link group lzma) doesn't exist
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libfakeroot:amd64 (1.22-2ubuntu1) ...
# Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up libice6:amd64 (2:1.0.9-2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libalgorithm-diff-perl (1.19.03-1) ...
# Setting up libxcb-shm0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up liblocale-gettext-perl (1.07-3build2) ...
# Setting up libx11-doc (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up shared-mime-info (1.9-2) ...
# Setting up libpcrecpp0v5:amd64 (2:8.39-9) ...
# Setting up libpcre32-3:amd64 (2:8.39-9) ...
# Setting up libmpc3:amd64 (1.1.0-1) ...
# Setting up icu-devtools (60.2-3ubuntu3.1) ...
# Setting up libc-dev-bin (2.27-3ubuntu1.4) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libpcre16-3:amd64 (2:8.39-9) ...
# Setting up libthai-data (0.1.27-2) ...
# Setting up bsdmainutils (11.1.2ubuntu1) ...
# update-alternatives: using /usr/bin/bsd-write to provide /usr/bin/write (write) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/write.1.gz because associated file /usr/share/man/man1/bsd-write.1.gz (of link group write) doesn't exist
# update-alternatives: using /usr/bin/bsd-from to provide /usr/bin/from (from) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/from.1.gz because associated file /usr/share/man/man1/bsd-from.1.gz (of link group from) doesn't exist
# Setting up libxft2:amd64 (2.3.2-1) ...
# Setting up manpages-dev (4.15-1) ...
# Setting up hicolor-icon-theme (0.17-2) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libglib2.0-bin (2.56.4-0ubuntu0.18.04.8) ...
# Setting up libc6-dev:amd64 (2.27-3ubuntu1.4) ...
# Setting up libgraphite2-dev:amd64 (1.3.11-2) ...
# Setting up libassuan0:amd64 (2.5.1-2) ...
# Setting up xdg-user-dirs (0.17-1ubuntu1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up x11proto-input-dev (2018.4-4) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up libitm1:amd64 (8.4.0-1ubuntu1~18.04) ...
# Setting up libpython2.7-stdlib:amd64 (2.7.17-1~18.04ubuntu1.6) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libmpdec2:amd64 (2.4.2-1ubuntu1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up fontconfig (2.12.6-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up zlib1g-dev:amd64 (1:1.2.11.dfsg-0ubuntu2) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up libisl19:amd64 (0.19-1) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up libcairo2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsm6:amd64 (2:1.2.2-1) ...
# Setting up libpcre3-dev:amd64 (2:8.39-9) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up python3.6 (3.6.9-1~18.04ubuntu1.4) ...
# Setting up x11proto-core-dev (2018.4-4) ...
# Setting up libltdl-dev:amd64 (2.4.6-2) ...
# Setting up libasan4:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libbinutils:amd64 (2.30-21ubuntu1~18.04.5) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libcilkrts5:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libubsan0:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up gpgconf (2.2.4-1ubuntu1.4) ...
# Setting up x11proto-fixes-dev (1:2018.4-4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Setting up libcairo-gobject2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up python2.7 (2.7.17-1~18.04ubuntu1.6) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libharfbuzz0b:amd64 (1.7.2-1ubuntu1) ...
# Setting up libxau-dev:amd64 (1:1.0.8-1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up libthai0:amd64 (0.1.27-2) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up fakeroot (1.22-2ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/fakeroot.1.gz because associated file /usr/share/man/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/faked.1.gz because associated file /usr/share/man/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/es/man1/fakeroot.1.gz because associated file /usr/share/man/es/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/es/man1/faked.1.gz because associated file /usr/share/man/es/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/fr/man1/fakeroot.1.gz because associated file /usr/share/man/fr/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/fr/man1/faked.1.gz because associated file /usr/share/man/fr/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/sv/man1/fakeroot.1.gz because associated file /usr/share/man/sv/man1/fakeroot-sysv.1.gz (of link group fakeroot) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/sv/man1/faked.1.gz because associated file /usr/share/man/sv/man1/faked-sysv.1.gz (of link group fakeroot) doesn't exist
# Setting up libgcc-7-dev:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up cpp-7 (7.5.0-3ubuntu1~18.04) ...
# Setting up libstdc++-7-dev:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up libpython-stdlib:amd64 (2.7.15~rc1-1) ...
# Setting up libalgorithm-merge-perl (0.08-3) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# Setting up libalgorithm-diff-xs-perl (0.04-5) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (1.7.2-1ubuntu1) ...
# Setting up libice-dev:amd64 (2:1.0.9-2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up gpgsm (2.2.4-1ubuntu1.4) ...
# Setting up libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/automake.1.gz because associated file /usr/share/man/man1/automake-1.15.1.gz (of link group automake) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/aclocal.1.gz because associated file /usr/share/man/man1/aclocal-1.15.1.gz (of link group automake) doesn't exist
# Setting up gnupg-utils (2.2.4-1ubuntu1.4) ...
# Setting up libexpat1-dev:amd64 (2.2.5-3ubuntu0.2) ...
# Setting up libxcb1-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up man-db (2.8.3-2ubuntu0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Building database of manual pages ...
# Setting up pinentry-curses (1.1.0-1) ...
# Setting up libx11-dev:amd64 (2:1.6.4-3ubuntu0.3) ...
# Setting up libpng-dev:amd64 (1.6.34-1ubuntu0.18.04.2) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-1) ...
# Setting up dirmngr (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libharfbuzz-gobject0:amd64 (1.7.2-1ubuntu1) ...
# Setting up python (2.7.15~rc1-1) ...
# Setting up gpg (2.2.4-1ubuntu1.4) ...
# Setting up binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.5) ...
# Setting up libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# Setting up cpp (4:7.4.0-1ubuntu2.3) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libsm-dev:amd64 (2:1.2.2-1) ...
# Setting up libharfbuzz-icu0:amd64 (1.7.2-1ubuntu1) ...
# Setting up po-debconf (1.0.20) ...
# Setting up python3 (3.6.7-1~18.04) ...
# running python rtupdate hooks for python3.6...
# running python post-rtupdate hooks for python3.6...
# Setting up libicu-le-hb0:amd64 (1.0.3+git161113-4) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libxdamage-dev:amd64 (1:1.1.4-3) ...
# Setting up gpg-agent (2.2.4-1ubuntu1.4) ...
# Setting up libxrender-dev:amd64 (1:0.9.10-1) ...
# Setting up gpg-wks-server (2.2.4-1ubuntu1.4) ...
# Setting up gpg-wks-client (2.2.4-1ubuntu1.4) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxcb-render0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libfreetype6-dev:amd64 (2.8.1-2ubuntu2.1) ...
# Setting up libxext-dev:amd64 (2:1.3.3-1) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libiculx60:amd64 (60.2-3ubuntu3.1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up binutils (2.30-21ubuntu1~18.04.5) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up python3-lib2to3 (3.6.9-1~18.04) ...
# Setting up python3-distutils (3.6.9-1~18.04) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libglib2.0-dev-bin (2.56.4-0ubuntu0.18.04.8) ...
# Setting up gcc-7 (7.5.0-3ubuntu1~18.04) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up g++-7 (7.5.0-3ubuntu1~18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up gnupg (2.2.4-1ubuntu1.4) ...
# Setting up libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up gcc (4:7.4.0-1ubuntu2.3) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up dpkg-dev (1.19.0.5ubuntu2.3) ...
# Setting up g++ (4:7.4.0-1ubuntu2.3) ...
# 7Progress: [ 95%] [#######################################################...] 8update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/c++.1.gz because associated file /usr/share/man/man1/g++.1.gz (of link group c++) doesn't exist
# Setting up libtool (2.4.6-2) ...
# Setting up librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up build-essential (12.4ubuntu1) ...
# Setting up librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up pkg-config (0.29.1-0ubuntu2) ...
# Setting up libfontconfig1-dev:amd64 (2.12.6-0ubuntu2) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libglib2.0-dev:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# Setting up libxft-dev (2.3.2-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up libharfbuzz-dev:amd64 (1.7.2-1ubuntu1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up adwaita-icon-theme (3.28.0-1ubuntu1) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up dh-autoreconf (17) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libicu-le-hb-dev:amd64 (1.0.3+git161113-4) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up humanity-icon-theme (0.6.15) ...
# Setting up libicu-dev (60.2-3ubuntu3.1) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
#
# 78

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Useful functions

# %%
## Return if the input image is gray or not.
def _isGray(I):
    return len(I.shape) == 2

## Convert image into float32 type.
def to32F(img):
    if img.dtype == np.float32:
        return img
    return (1.0 / 255.0) * np.float32(img)

# %% [markdown]
# ## Guided filter for black and white

# %%
## Guided filter for gray guidance image.
class GuidedFilterGray:
    #  @param I Input gray guidance image.
    #  @param radius Radius of Guided Filter.
    #  @param epsilon Regularization term of Guided Filter.
    #  I: Guided image
    #  R: Radius for the box filter
    #  Epsilon: regularization parameter
    #  p: Input image
    #  q: Output image 
    def __init__(self, I, radius=5, epsilon=0.4):
        self._radius = 2 * radius + 1
        self._epsilon = epsilon
        self._I = to32F(I)
        self._initFilter()

    ## Apply filter for the input image.
    #  @param p Input image for the filtering.
    def filter(self, p):
        p_32F = to32F(p)
        ab = self._computeCoefficients(p_32F)
        return self._computeOutput(ab, self._I)

    def _initFilter(self):
        I = self._I
        r = self._radius
        self._I_mean = cv2.blur(I, (r, r))
        I_mean_sq = cv2.blur(I ** 2, (r, r))
        self._I_var = I_mean_sq - self._I_mean ** 2

    def _computeCoefficients(self, p):
        r = self._radius
        p_mean = cv2.blur(p, (r, r))
        I_p_corr = cv2.blur(self._I * p, (r, r))
        p_cov = I_p_corr - self._I_mean * p_mean
        a = p_cov / (self._I_var + self._epsilon)
        b = p_mean - a * self._I_mean
        a_mean = cv2.blur(a, (r, r))
        b_mean = cv2.blur(b, (r, r))
        return a_mean, b_mean

    def _computeOutput(self, ab, I):
        a_mean, b_mean = ab
        return a_mean * I + b_mean

# %% [markdown]
# ## Guided filter for color image

# %%
## Guided filter for gray guidance image.
class GuidedFilterColor:
    #  @param I Input gray guidance image.
    #  @param radius Radius of Guided Filter.
    #  @param epsilon Regularization term of Guided Filter.
    #  I: Guided image
    #  R: Radius for the box filter
    #  Epsilon: regularization parameter
    #  p: Input image
    #  q: Output image 
    def __init__(self, I, radius=5, epsilon=0.4):
        self._radius = 2 * radius + 1
        self._epsilon = epsilon
        self._I = to32F(I)
        self._initFilter()

    ## Apply filter for the input image.
    #  @param p Input image for the filtering.
    def filter(self, p):
        p_32F = to32F(p)

        cs = p.shape[2]
        q = np.array(p_32F)

        for ci in range(cs):
            q[:, :, ci] = self._filterGray(p_32F[:, :, ci])
        return q
        
    def _filterGray(self, p):
        ab = self._computeCoefficients(p)
        return self._computeOutput(ab, self._I)

    def _initFilter(self):
        I = self._I
        r = self._radius
        eps = self._epsilon

        Ir, Ig, Ib = I[:, :, 0], I[:, :, 1], I[:, :, 2]

        self._Ir_mean = cv2.blur(Ir, (r, r))
        self._Ig_mean = cv2.blur(Ig, (r, r))
        self._Ib_mean = cv2.blur(Ib, (r, r))

        Irr_var = cv2.blur(Ir ** 2, (r, r)) - self._Ir_mean ** 2 + eps
        Irg_var = cv2.blur(Ir * Ig, (r, r)) - self._Ir_mean * self._Ig_mean
        Irb_var = cv2.blur(Ir * Ib, (r, r)) - self._Ir_mean * self._Ib_mean
        Igg_var = cv2.blur(Ig * Ig, (r, r)) - self._Ig_mean * self._Ig_mean + eps
        Igb_var = cv2.blur(Ig * Ib, (r, r)) - self._Ig_mean * self._Ib_mean
        Ibb_var = cv2.blur(Ib * Ib, (r, r)) - self._Ib_mean * self._Ib_mean + eps

        Irr_inv = Igg_var * Ibb_var - Igb_var * Igb_var
        Irg_inv = Igb_var * Irb_var - Irg_var * Ibb_var
        Irb_inv = Irg_var * Igb_var - Igg_var * Irb_var
        Igg_inv = Irr_var * Ibb_var - Irb_var * Irb_var
        Igb_inv = Irb_var * Irg_var - Irr_var * Igb_var
        Ibb_inv = Irr_var * Igg_var - Irg_var * Irg_var

        I_cov = Irr_inv * Irr_var + Irg_inv * Irg_var + Irb_inv * Irb_var
        Irr_inv /= I_cov
        Irg_inv /= I_cov
        Irb_inv /= I_cov
        Igg_inv /= I_cov
        Igb_inv /= I_cov
        Ibb_inv /= I_cov

        self._Irr_inv = Irr_inv
        self._Irg_inv = Irg_inv
        self._Irb_inv = Irb_inv
        self._Igg_inv = Igg_inv
        self._Igb_inv = Igb_inv
        self._Ibb_inv = Ibb_inv

    def _computeCoefficients(self, p):
        r = self._radius
        I = self._I
        Ir, Ig, Ib = I[:, :, 0], I[:, :, 1], I[:, :, 2]

        p_mean = cv2.blur(p, (r, r))

        Ipr_mean = cv2.blur(Ir * p, (r, r))
        Ipg_mean = cv2.blur(Ig * p, (r, r))
        Ipb_mean = cv2.blur(Ib * p, (r, r))

        Ipr_cov = Ipr_mean - self._Ir_mean * p_mean
        Ipg_cov = Ipg_mean - self._Ig_mean * p_mean
        Ipb_cov = Ipb_mean - self._Ib_mean * p_mean

        ar = self._Irr_inv * Ipr_cov + self._Irg_inv * Ipg_cov + self._Irb_inv * Ipb_cov
        ag = self._Irg_inv * Ipr_cov + self._Igg_inv * Ipg_cov + self._Igb_inv * Ipb_cov
        ab = self._Irb_inv * Ipr_cov + self._Igb_inv * Ipg_cov + self._Ibb_inv * Ipb_cov
        b = p_mean - ar * self._Ir_mean - ag * self._Ig_mean - ab * self._Ib_mean

        ar_mean = cv2.blur(ar, (r, r))
        ag_mean = cv2.blur(ag, (r, r))
        ab_mean = cv2.blur(ab, (r, r))
        b_mean = cv2.blur(b, (r, r))

        return ar_mean, ag_mean, ab_mean, b_mean

    def _computeOutput(self, ab, I):
        ar_mean, ag_mean, ab_mean, b_mean = ab

        Ir, Ig, Ib = I[:, :, 0], I[:, :, 1], I[:, :, 2]

        q = (ar_mean * Ir +
             ag_mean * Ig +
             ab_mean * Ib +
             b_mean)

        return q

# %% [markdown]
# ## Noise removal in black and white image

# %%
I = cv2.imread("cat.png", 0)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(I, cmap="gray")
plt.axis('off')
plt.savefig("./output/cat_guidance.png",bbox_inches='tight', transparent = True, pad_inches = 0)

h, w = I.shape
p = np.float32(I + 50 * np.random.randn(h, w))
p = np.clip(p, 0.0, 255.0)

plt.figure()
# plt.title("Noisy Input Image")
plt.imshow(p, cmap="gray")
plt.axis('off')
plt.savefig("./output/cat_input.png",bbox_inches='tight', transparent = True, pad_inches = 0)

obj=GuidedFilterGray(I, radius=10, epsilon=0.001)
q = obj.filter(p)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(q, cmap="gray")
plt.axis('off')
plt.savefig("./output/cat_gf.png",bbox_inches='tight', transparent = True, pad_inches = 0)

# %% [markdown]
# ## Noise removal in RGB image

# %%
I = cv2.imread("tulips.png")
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(np.uint8(I))
plt.axis('off')
plt.savefig("./output/tulip_guidance.png",bbox_inches='tight', transparent = True, pad_inches = 0)

h, w, cs = I.shape
p = I + 255 * np.random.random((h, w, cs)) - 100
p = np.clip(p, 0.0, 255.0)

plt.figure()
# plt.title("Noisy Image")
plt.imshow(np.uint8(p))
plt.axis('off')
plt.savefig("./output/tulip_input.png",bbox_inches='tight', transparent = True, pad_inches = 0)

obj=GuidedFilterColor(I, radius=20, epsilon=0.0009)
q = obj.filter(p)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(np.uint8(q * 255.0))
plt.axis('off')
plt.savefig("./output/tulip_gf.png",bbox_inches='tight', transparent = True, pad_inches = 0)

# %% [markdown]
# ## Structure-Transferring Filtering

# %%
I = cv2.imread("toy.png")
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(np.uint8(I))
plt.axis('off')
plt.savefig("./output/toy_guidance.png",bbox_inches='tight', transparent = True, pad_inches = 0)

p = cv2.imread("toy-mask.png")
p = cv2.cvtColor(p, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Noisy Image")
plt.imshow(np.uint8(p))
plt.axis('off')
plt.savefig("./output/toy_input.png",bbox_inches='tight', transparent = True, pad_inches = 0)

obj=GuidedFilterColor(I, radius=20, epsilon=0.045)
q = obj.filter(p)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(np.uint8(q * 255.0))
plt.axis('off')
plt.savefig("./output/toy_gf.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

# %% [markdown]
# ## Flash/No-Flash De-noising

# %%
I = cv2.imread("cave-flash.png")
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(np.uint8(I))
plt.axis('off')
plt.savefig("./output/cave_guidance.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

p = cv2.imread("cave-noflash.png")
p = cv2.cvtColor(p, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Noisy Image")
plt.imshow(np.uint8(p))
plt.axis('off')
plt.savefig("./output/cave_input.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

obj=GuidedFilterColor(I, radius=7, epsilon=0.003)
q = obj.filter(p)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(np.uint8(q * 255.0))
plt.axis('off')
plt.savefig("./output/cave_gf.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

# %% [markdown]
# ## Image enhancement

# %%
I = cv2.imread("tulips.png")
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(I)
plt.axis('off')
plt.savefig("./output/tulips_guidance.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

p = cv2.imread("tulips-smoothed.png")
p = cv2.cvtColor(p, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Smoothed Image")
plt.imshow(p)
plt.axis('off')
plt.savefig("./output/tulips_input.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

obj=GuidedFilterColor(I, radius=30, epsilon=0.001)
q = obj.filter(p)
q = np.uint8(q * 255.0)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(q)
plt.axis('off')
plt.savefig("./output/tulips_gf.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

# %%
I = cv2.imread("Horse.jpg")
I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Guidance Image")
plt.imshow(np.uint8(I))
plt.axis('off')
plt.savefig("./output/horse_guidance.png",bbox_inches='tight', transparent = True, pad_inches = 0)

p = cv2.imread("Horse_label.png")
p = cv2.cvtColor(p, cv2.COLOR_BGR2RGB)

plt.figure()
# plt.title("Noisy Image")
plt.imshow(np.uint8(p))
plt.axis('off')
plt.savefig("./output/horse_input.png",bbox_inches='tight', transparent = True, pad_inches = 0)

obj=GuidedFilterColor(I, radius=10, epsilon=0.08)
q = obj.filter(p)

plt.figure()
# plt.title("Guided filter applied image")
plt.imshow(np.uint8(q * 255.0))
plt.axis('off')
plt.savefig("./output/horse_gf.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)

# %%
q=np.uint8(q * 255.0)
gauss_mask = cv2.GaussianBlur(q, (5, 5), 0.0)
c_man_sharp = cv2.addWeighted(q, 3, gauss_mask, -2, 0)
plt.imshow(c_man_sharp)
plt.axis('off')
plt.savefig("./output/horse_gf_hb.png", bbox_inches = 'tight', transparent = True, pad_inches = 0)
